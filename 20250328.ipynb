# %% [markdown]
# <a href="https://colab.research.google.com/github/jth202515033/ABCD-A/blob/20250328/20250328.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자 = 50000
총평가금액 = 삼성전자 * 10
print(총평가금액)
# Out:
# 500000

# %%
시가총액 = 29800000000000
현재가 = 50000
PER = 15.79
print("시가총액", type(int(시가총액)))
print("현재가" , type(int(현재가)))
print("PER" , type(float(PER)))
# Out:
# 시가총액 <class 'int'>
# 현재가 <class 'int'>
# PER <class 'float'>

# %%
s = "hello! "
t = "python"
print(s + t)
# Out:
# hello! python

# %%
X = 2
Y = 3
print(X+X*Y)
# Out:
# 8
