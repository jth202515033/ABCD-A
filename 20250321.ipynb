# %% [markdown]
# <a href="https://colab.research.google.com/github/jth202515033/ABCD-A/blob/20250321/20250321.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
1 / 2
# Out:
# 0.5

# %%
4 / 2
# Out:
# 2.0

# %%
7 // 3
# Out:
# 2

# %%
7 % 3
# Out:
# 1

# %%
2 ** 10
# Out:
# 1024

# %%
int(5 / 2)
# Out:
# 2

# %%
5 // 2
# Out:
# 2

# %%
a = 1024
print(a)
# Out:
# 1024

# %%
a += 1024
a
# Out:
# 15360

# %%
a *=4
a
# Out:
# 245760

# %%
a//= 2
a
# Out:
# 122880

# %%
a %= 1022
a
# Out:
# 240

# %%
a **= 10
a
# Out:
# ...

# %%
divmod(5, 2)
# Out:
# (2, 1)

# %%
quotient, remainder = divmod(5, 2)
print(quotient, remainder)
# Out:
# 2 1

# %%
a = 11 + 2
b = 12 - 2
c = 13 * 2
d = 14 / 2
e = 15 ** 2
f = 16 // 2
g = 17 % 3

print(a, b, c, d, e, f, g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
a = 10
++a
print(a)
# Out:
# 10

# %%
a = 10
b = 3
print("10 == 3==>", a == b )
print("10 != 3 =>", a != b)
print("10 > 3 =>", a > b)
print("10 >= 3 =>", a >= b)
print("10 < 3 =>", a < b)
print("10 <= 3 =>", a <= b)
print()
# Out:
# 10 == 3==> False
# 10 != 3 => True
# 10 > 3 => True
# 10 >= 3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
bin(13)
# Out:
# '0b1101'

# %%
0b1101
# Out:
# 13

# %%
int('1101' ,  2 )
# Out:
# 13

# %%
bin(0b1101 & 0b1101)
# Out:
# '0b1101'

# %%
13 & 9
# Out:
# 9

# %%
13 | 9
# Out:
# 13

# %%
bin(0b1101 ^ 0b1101)
# Out:
# '0b0'

# %%
13 ^ 9
# Out:
# 4

# %%
bin(~0b1101)
# Out:
# '-0b1110'

# %%
~13
# Out:
# -14

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)
# Out:
# 0b1101
# 0b1001
# 0b1101
# 13

# %%
a = 12
b = 8
print(print(a))
print(print(b))
print(bin(a^b))
print('')
print(a^b)
# Out:
# 12
# None
# 8
# None
# 0b100
#
# 4

# %%
a = 12
b = 8
print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# -0b1101
